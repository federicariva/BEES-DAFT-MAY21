# %% [markdown]
# # Federica's Jupyter notebook

# %% [markdown]
# **First day**

# %% [markdown]
# The purpose of the notebook is to introduce a friend of mine and her holidays preference

# %%
#asking for the name of the friend
name = input ("What is your friend's name? ")
# Out:
# What is your friend's name? Olga

# %%
print ("This is my friend " + name)
# Out:
# This is my friend Olga

# %% [markdown]
# ![Olga.jpg](attachment:Olga.jpg)

# %%
favorite_holiday = input("What is your friend's favorite holiday? ")
print ("My friend's favorite holiday is " + favorite_holiday)
# Out:
# What is your friend's favorite holiday?Australia
# My friend's favorite holiday is Australia

# %%
print ("This is " + name + "'s " + "favorite holiday destination: " + favorite_holiday)
# Out:
# This is Olga's favorite holiday destination: Australia

# %%
from IPython.display import Image
Image(url='https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/holger-link-704031-unsplash-1549277325.jpg?resize=480:*', width=400)
# Out:
# <img src="https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/holger-link-704031-unsplash-1549277325.jpg?resize=480:*" width="400"/>

# %% [markdown]
# Best things to do in Australia:
# - Visting parks
# - Explore the cities
# - Practicing water sports

# %% [markdown]
# <span style="color:blue"> __Best things to do in Australia:__
#     Visting parks
#     Explore the cities
#     Practicing water sports</span>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('PdVLk_dPmtc')
